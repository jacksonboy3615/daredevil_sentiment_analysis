# %%
import pandas as pd
import numpy as np
import requests
# from bs4 import BeautifulSoup as bs
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import time

# %%
user_rating = []
review_date = []
review_title = []
review = []
likes = []
dislikes = []

url = 'https://www.imdb.com/title/tt3322312/reviews/'
# option = webdriver.ChromeOptions()
# option.add_argument("headless")
driver = webdriver.Chrome()
driver.get(url)

see_all = driver.find_element(By.XPATH, '//*[@id="__next"]/main/div/section/div/section/div/div[1]/section[1]/div[3]/div/span[2]/button')

while True:
    try:
        see_all.send_keys(Keys.ENTER)
        time.sleep(120)
    except Exception as e:
        break

for i in range(1,1341):
    try:
        rating =  driver.find_element(By.XPATH, '//*[@id="__next"]/main/div/section/div/section/div/div[1]/section[1]/article[{}]/div[1]/div[1]/div[1]/span/span[1]'.format(1*i)).text
        date = driver.find_element(By.XPATH, '//*[@id="__next"]/main/div/section/div/section/div/div[1]/section[1]/article[{}]/div[2]/ul/li[2]'.format(1*i)).text
        title = driver.find_element(By.XPATH, '//*[@id="__next"]/main/div/section/div/section/div/div[1]/section[1]/article[{}]/div[1]/div[1]/div[2]/div/a/h3'.format(1*i)).text
        review_content = driver.find_element(By.XPATH, '//*[@id="__next"]/main/div/section/div/section/div/div[1]/section[1]/article[{}]/div[1]/div[1]/div[3]/div/div/div'.format(1*i)).text
        like = driver.find_element(By.XPATH, '//*[@id="__next"]/main/div/section/div/section/div/div[1]/section[1]/article[{}]/div[1]/div[2]/div[1]/div/span[1]/span[3]'.format(1*i)).text
        dislike = driver.find_element(By.XPATH, '//*[@id="__next"]/main/div/section/div/section/div/div[1]/section[1]/article[{}]/div[1]/div[2]/div[1]/div/span[2]/span'.format(1*i)).text

        user_rating.append(rating)
        review_date.append(date)
        review_title.append(title)
        review.append(review_content)
        likes.append(like)
        dislikes.append(dislike)

    except:
        continue

# %%
print(len(user_rating), len(review_date), len(review_title),  len(review), len(likes), len(dislikes))
# Out:
# 1078 1078 1078 1078 1078 1078

# %%
daredevil_sentiment_raw = {'User_Ratings': user_rating, 
                           'Review_Dates': review_date,
                           'Titles': review_title,
                           'Reviews': review,
                           'Likes': likes,
                           'Dislikes': dislikes}

daredevil_sentiment_df = pd.DataFrame(daredevil_sentiment_raw)

# %%
daredevil_sentiment_df
# Out:
#      User_Ratings  Review_Dates  \
# 0              10  Feb 26, 2019
# 1               9  Oct 20, 2018
# 2              10  Mar 26, 2019
# 3              10  Dec 10, 2023
# 4              10  Apr 16, 2020
# ...           ...           ...
# 1073           10  Oct 28, 2018
# 1074           10  Apr 19, 2015
# 1075           10   Jun 3, 2017
# 1076           10  Feb 26, 2019
# 1077            9  Oct 20, 2018
#
#                                                  Titles  \
# 0         Daredevil won't stay down and neither will we
# 1                                           Season 3...
# 2                  Easily the Best Show I've Ever Seen!
# 3                                    Absolutely Awesome
# 4     If DC has The Dark Knight trilogy, well Marvel...
# ...                                                 ...
# 1073                                     AMAZING OMG!!!
# 1074                       Frank Miller would be Proud!
# 1075         1 of the best superhero shows ever on TV!!
# 1076      Daredevil won't stay down and neither will we
# 1077                                        Season 3...
#
#                                                 Reviews Likes Dislikes
# 0     I was gutted when Daredevil was cancelled. Eas...   418       27
# 1     Let me start by saying Daredevil season 1 was ...   528       38
# 2     I seriously don't understand why Netflix would...   354       29
# 3     Daredevil was such an incredible show! Charlie...   145        9
# 4     This is not your average super hero show. I lo...   278       22
# ...                                                 ...   ...      ...
# 1073  This is must watch series on Netflix.... neat ...     0        1
# 1074  It's obvious the Producers of this show did th...     0        7
# 1075  Daredevil!!\n\nFirst of all, I am a big fan of...     0        0
# 1076  I was gutted when Daredevil was cancelled. Eas...   418       27
# 1077  Let me start by saying Daredevil season 1 was ...   528       38
#
# [1078 rows x 6 columns]

# %%
daredevil_sentiment_clean_df = daredevil_sentiment_df.drop_duplicates()

daredevil_sentiment_clean_df
# Out:
#      User_Ratings  Review_Dates  \
# 0              10  Feb 26, 2019
# 1               9  Oct 20, 2018
# 2              10  Mar 26, 2019
# 3              10  Dec 10, 2023
# 4              10  Apr 16, 2020
# ...           ...           ...
# 1071            9  Apr 30, 2019
# 1072            9  Apr 28, 2015
# 1073           10  Oct 28, 2018
# 1074           10  Apr 19, 2015
# 1075           10   Jun 3, 2017
#
#                                                  Titles  \
# 0         Daredevil won't stay down and neither will we
# 1                                           Season 3...
# 2                  Easily the Best Show I've Ever Seen!
# 3                                    Absolutely Awesome
# 4     If DC has The Dark Knight trilogy, well Marvel...
# ...                                                 ...
# 1071                                 One of the best!!!
# 1072                   This is actually very well done!
# 1073                                     AMAZING OMG!!!
# 1074                       Frank Miller would be Proud!
# 1075         1 of the best superhero shows ever on TV!!
#
#                                                 Reviews Likes Dislikes
# 0     I was gutted when Daredevil was cancelled. Eas...   418       27
# 1     Let me start by saying Daredevil season 1 was ...   528       38
# 2     I seriously don't understand why Netflix would...   354       29
# 3     Daredevil was such an incredible show! Charlie...   145        9
# 4     This is not your average super hero show. I lo...   278       22
# ...                                                 ...   ...      ...
# 1071  The show is one of the best you will find in s...     0        0
# 1072  I wasn't expecting much from this series as it...     0        4
# 1073  This is must watch series on Netflix.... neat ...     0        1
# 1074  It's obvious the Producers of this show did th...     0        7
# 1075  Daredevil!!\n\nFirst of all, I am a big fan of...     0        0
#
# [1076 rows x 6 columns]

# %%
daredevil_sentiment_clean_df['Series'] = "Daredevil"
daredevil_sentiment_clean_df['Network'] = "Netflix"

daredevil_sentiment_clean_df
# Out:
# C:\Users\Jack Kim\AppData\Local\Temp\ipykernel_6156\623194579.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   daredevil_sentiment_clean_df['Series'] = "Daredevil"
# C:\Users\Jack Kim\AppData\Local\Temp\ipykernel_6156\623194579.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   daredevil_sentiment_clean_df['Network'] = "Netflix"
#      User_Ratings  Review_Dates  \
# 0              10  Feb 26, 2019
# 1               9  Oct 20, 2018
# 2              10  Mar 26, 2019
# 3              10  Dec 10, 2023
# 4              10  Apr 16, 2020
# ...           ...           ...
# 1071            9  Apr 30, 2019
# 1072            9  Apr 28, 2015
# 1073           10  Oct 28, 2018
# 1074           10  Apr 19, 2015
# 1075           10   Jun 3, 2017
#
#                                                  Titles  \
# 0         Daredevil won't stay down and neither will we
# 1                                           Season 3...
# 2                  Easily the Best Show I've Ever Seen!
# 3                                    Absolutely Awesome
# 4     If DC has The Dark Knight trilogy, well Marvel...
# ...                                                 ...
# 1071                                 One of the best!!!
# 1072                   This is actually very well done!
# 1073                                     AMAZING OMG!!!
# 1074                       Frank Miller would be Proud!
# 1075         1 of the best superhero shows ever on TV!!
#
#                                                 Reviews Likes Dislikes  \
# 0     I was gutted when Daredevil was cancelled. Eas...   418       27
# 1     Let me start by saying Daredevil season 1 was ...   528       38
# 2     I seriously don't understand why Netflix would...   354       29
# 3     Daredevil was such an incredible show! Charlie...   145        9
# 4     This is not your average super hero show. I lo...   278       22
# ...                                                 ...   ...      ...
# 1071  The show is one of the best you will find in s...     0        0
# 1072  I wasn't expecting much from this series as it...     0        4
# 1073  This is must watch series on Netflix.... neat ...     0        1
# 1074  It's obvious the Producers of this show did th...     0        7
# 1075  Daredevil!!\n\nFirst of all, I am a big fan of...     0        0
#
#          Series  Network
# 0     Daredevil  Netflix
# 1     Daredevil  Netflix
# 2     Daredevil  Netflix
# 3     Daredevil  Netflix
# 4     Daredevil  Netflix
# ...         ...      ...
# 1071  Daredevil  Netflix
# 1072  Daredevil  Netflix
# 1073  Daredevil  Netflix
# 1074  Daredevil  Netflix
# 1075  Daredevil  Netflix
#
# [1076 rows x 8 columns]

# %%
daredevil_sentiment_clean_df.to_csv('daredevil_netflix_sentiment.csv')
