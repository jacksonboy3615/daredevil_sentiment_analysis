# %%
# pip install wordcloud

# %%
import numpy as np
import pandas as pd
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
from PIL import Image

# %%
born_again_prep = pd.read_csv('daredevil_born_again_sentiment.csv')

# %%
born_again_df = born_again_prep.drop('Unnamed: 0', axis=1)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
sentiment_vader = SentimentIntensityAnalyzer()
born_again_df['Title_Sentiment_Score'] = born_again_df['Titles'].apply(lambda text: sentiment_vader.polarity_scores(text)['compound'])
born_again_df['Review_Sentiment_Score'] = born_again_df['Reviews'].apply(lambda text: sentiment_vader.polarity_scores(text)['compound'])

def sentiment_category_vader(sentiment):
        if sentiment >= 0.05:
            return "Positive"
        elif sentiment <= -0.05:
            return "Negative"
        else:
            return "Neutral"
        
born_again_df['Title_sentiment_Vader'] = born_again_df['Title_Sentiment_Score'].apply(sentiment_category_vader)
born_again_df['Review_Sentiment_Vader'] = born_again_df['Review_Sentiment_Score'].apply(sentiment_category_vader)

born_again_df
# Out:
#      User_Ratings  Review_Dates  \
# 0               9   Aug 9, 2025
# 1               8  Jul 11, 2025
# 2              10   Aug 9, 2025
# 3               9  Jul 26, 2025
# 4               8   Jul 6, 2025
# ..            ...           ...
# 302             4  Apr 18, 2025
# 303             5  Apr 20, 2025
# 304             5   Mar 6, 2025
# 305             3  Apr 21, 2025
# 306             4  Apr 18, 2025
#
#                                              Titles  \
# 0                                 Daredevil is back
# 1                                     Solid revival
# 2                                         Fantastic
# 3                                         call Rome
# 4    A Solid Return for the Devil of Hell's Kitchen
# ..                                              ...
# 302                     An insult to Netflix's D.D.
# 303                          Very Meh...Very Disney
# 304                                   S tier Marvel
# 305                Clearly not the Netflix version.
# 306                               Lukewarm wannabe.
#
#                                                Reviews  Likes  Dislikes  \
# 0    I can't tell you how glad I am that Daredevil ...     71         1
# 1    Daredevil: Born Again was announced several ye...     54         3
# 2    I don't even know where to begin in describing...     66         3
# 3    Historians of the far future looking back at o...     48         3
# 4    This spiritual sequel doesn't try to be Season...     48         3
# ..                                                 ...    ...       ...
# 302  A huge disappointment after waiting a long tim...      3         3
# 303  Overall, it was just ok. Nowhere near as good ...      7        13
# 304  Okay i am a Marvel Comic Book fan that has bee...      9        23
# 305  Poorly written without loyalty to the true cha...      6        13
# 306  While this new thing was airing I had to go ba...      4         7
#
#                     Series  Network  Title_Sentiment_Score  \
# 0    Daredevil: Born Again  Disney+                 0.1280
# 1    Daredevil: Born Again  Disney+                 0.1531
# 2    Daredevil: Born Again  Disney+                 0.5574
# 3    Daredevil: Born Again  Disney+                 0.0000
# 4    Daredevil: Born Again  Disney+                -0.5859
# ..                     ...      ...                    ...
# 302  Daredevil: Born Again  Disney+                -0.5106
# 303  Daredevil: Born Again  Disney+                 0.0000
# 304  Daredevil: Born Again  Disney+                 0.4215
# 305  Daredevil: Born Again  Disney+                 0.4019
# 306  Daredevil: Born Again  Disney+                 0.0000
#
#      Review_Sentiment_Score Title_sentiment_Vader Review_Sentiment_Vader
# 0                    0.9917              Positive               Positive
# 1                    0.9663              Positive               Positive
# 2                    0.9184              Positive               Positive
# 3                    0.9787               Neutral               Positive
# 4                    0.9929              Negative               Positive
# ..                      ...                   ...                    ...
# 302                 -0.9643              Negative               Negative
# 303                  0.8725               Neutral               Positive
# 304                  0.9776              Positive               Positive
# 305                 -0.9777              Positive               Negative
# 306                  0.4597               Neutral               Positive
#
# [307 rows x 12 columns]

# %%
reviews = ' '.join(born_again_df['Reviews'])

kingpin_mask = np.array(Image.open("kingpin2-removebg-preview.png"))

kingpin_mask

# replace 0 with 255
kingpin_mask[kingpin_mask == 0] = 255
kingpin_mask

wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="rgba(255, 255, 255, 0)", mode="RGBA", mask=kingpin_mask, collocations=False).generate(reviews)

wordcloud.words_

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud.to_file("kingpin_wordcloud2.png")

# %%
word_frequency = wordcloud.words_

words = word_frequency

word_frequency_born_again = pd.DataFrame(list(words.items()), columns=['words', 'frequency']) 

word_frequency_born_again.to_csv('word_frequency_born_again.csv')
